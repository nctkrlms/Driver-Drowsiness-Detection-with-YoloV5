# %%
# !pip install torch==1.8.2+cpu torchvision==0.9.2+cpu torchaudio===0.8.2 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# ...

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\users\\necati\\anaconda3\\lib\\site-packages\\numpy-1.21.3.dist-info\\METADATA'

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
import uuid   # Unique identifier
import os
import time

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 1
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data\hyps\hyp.scratch.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=1, project=runs\train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  v6.0-39-g5d4258f torch 1.10.0+cpu CPU
#
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp20/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\Necati/.cache\torch\hub\master.zip
# requirements: matplotlib>=3.2.2 not found and is required by YOLOv5, attempting auto-update...
# YOLOv5  2021-11-13 torch 1.8.2+cpu CPU
# requirements: Command 'pip install 'matplotlib>=3.2.2'' returned non-zero exit status 1.
# Fusing layers...
# Model Summary: 213 layers, 7069459 parameters, 0 gradients, 16.0 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'necatibey.jpg')
results = model(img)

# %%
results.print()
plt.imshow(np.squeeze(results.render()))
plt.savefig("necatibey.jpeg")
# Out:
# image 1/1: 1024x768 3 lefteyes, 1 openedeye, 1 awake
# Speed: 31.9ms pre-process, 188.5ms inference, 1.0ms NMS per image at shape (1, 3, 640, 480)

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    results = model(frame)
    cv2.imshow('YOLO', np.squeeze(results.render()))
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
